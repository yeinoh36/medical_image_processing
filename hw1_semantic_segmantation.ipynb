# %%
from google.colab import drive
import os

drive.mount('/content/drive/')

# 작업 경로를 MyDrive로 변경하여 구글 드라이브에 접속 후 바로 작업 디렉토리를 확인 가능

print('현재 작업 경로 :', os.getcwd())
os.chdir('/content/drive/MyDrive')
print('변경된 작업 경로 :', os.getcwd())
# Out:
# Mounted at /content/drive/
# 현재 작업 경로 : /content
# 변경된 작업 경로 : /content/drive/MyDrive

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img
from PIL import ImageOps

from tensorflow import keras
import numpy as np
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras import layers

# %%
# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Build model
#model = get_model(img_size, num_classes)
#model.summary()
from glob import glob

# %%
# !pip install opencv-python numpy

# %%
import cv2
import numpy as np

image = cv2.imread("/content/drive/MyDrive/sample_image/sample_image.png")  # 이미지 파일 경로
mask = np.zeros_like(image, dtype=np.uint8)  # 빈 마스크 생성

import json

with open("/content/drive/MyDrive/sample_image/sample_image.json", "r") as json_file:  # JSON 파일 경로
    data = json.load(json_file)
    for obj in data["shapes"]:
        class_name = obj["label"]
        coordinates = obj["points"]
        pts = np.array(coordinates, np.int32)
        cv2.fillPoly(mask, [pts], (255, 255, 255))  # 마스크에 다각형 영역 채우기

from google.colab.patches import cv2_imshow

# 마스크 확인
cv2_imshow(mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# 마스크 저장
cv2.imwrite("mask.png", mask)
# Out:
# <PIL.Image.Image image mode=RGB size=767x463>
# True

# %%
image = cv2.imread("/content/drive/MyDrive/sample_image/sample_image2.png")  # 이미지 파일 경로
mask = np.zeros_like(image, dtype=np.uint8)  # 빈 마스크 생성

import json

with open("/content/drive/MyDrive/sample_image/sample_image2.json", "r") as json_file:  # JSON 파일 경로
    data = json.load(json_file)
    for obj in data["shapes"]:
        class_name = obj["label"]
        coordinates = obj["points"]
        pts = np.array(coordinates, np.int32)
        cv2.fillPoly(mask, [pts], (255, 255, 255))  # 마스크에 다각형 영역 채우기

from google.colab.patches import cv2_imshow

# 마스크 확인
cv2_imshow(mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# 마스크 저장
cv2.imwrite("mask2.png", mask)
# Out:
# <PIL.Image.Image image mode=RGB size=342x215>
# True

# %%
image = cv2.imread("/content/drive/MyDrive/sample_image/sample_image3.png")  # 이미지 파일 경로
mask = np.zeros_like(image, dtype=np.uint8)  # 빈 마스크 생성

import json

with open("/content/drive/MyDrive/sample_image/sample_image3.json", "r") as json_file:  # JSON 파일 경로
    data = json.load(json_file)
    for obj in data["shapes"]:
        class_name = obj["label"]
        coordinates = obj["points"]
        pts = np.array(coordinates, np.int32)
        cv2.fillPoly(mask, [pts], (255, 255, 255))  # 마스크에 다각형 영역 채우기

from google.colab.patches import cv2_imshow

# 마스크 확인
cv2_imshow(mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# 마스크 저장
cv2.imwrite("mask3.png", mask)
# Out:
# <PIL.Image.Image image mode=RGB size=176x122>
# True

# %%
image = cv2.imread("/content/drive/MyDrive/sample_image/sample_image4.png")  # 이미지 파일 경로
mask = np.zeros_like(image, dtype=np.uint8)  # 빈 마스크 생성

import json

with open("/content/drive/MyDrive/sample_image/sample_image4.json", "r") as json_file:  # JSON 파일 경로
    data = json.load(json_file)
    for obj in data["shapes"]:
        class_name = obj["label"]
        coordinates = obj["points"]
        pts = np.array(coordinates, np.int32)
        cv2.fillPoly(mask, [pts], (255, 255, 255))  # 마스크에 다각형 영역 채우기

from google.colab.patches import cv2_imshow

# 마스크 확인
cv2_imshow(mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# 마스크 저장
cv2.imwrite("mask4.png", mask)
# Out:
# <PIL.Image.Image image mode=RGB size=231x131>
# True

# %%
image = cv2.imread("/content/drive/MyDrive/sample_image/sample_image5.png")  # 이미지 파일 경로
mask = np.zeros_like(image, dtype=np.uint8)  # 빈 마스크 생성

import json

with open("/content/drive/MyDrive/sample_image/sample_image5.json", "r") as json_file:  # JSON 파일 경로
    data = json.load(json_file)
    for obj in data["shapes"]:
        class_name = obj["label"]
        coordinates = obj["points"]
        pts = np.array(coordinates, np.int32)
        cv2.fillPoly(mask, [pts], (255, 255, 255))  # 마스크에 다각형 영역 채우기

from google.colab.patches import cv2_imshow

# 마스크 확인
cv2_imshow(mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# 마스크 저장
cv2.imwrite("mask5.png", mask)
# Out:
# <PIL.Image.Image image mode=RGB size=367x302>
# True

# %%
# 데이터 파일의 위치 변경을 위한 함수 생성
import os
import sys
import sqlite3
import traceback
import logging

logger = logging.getLogger('wpg_logger')
logging.basicConfig(encoding='utf-8', level=logging.INFO, format='%(levelname)s:%(name)s:%(asctime)s:%(message)s', filename='./logger.log', filemode='a')
logger.info('[Start]')

rootPath="/content"

logger.info('[makeDir]')
# 폴더 체크 후 없으면 생성
def makeDir(rootPath, dir):
  # root 경로에 원하는 폴더 이름 합치기
  dirPath = rootPath + "/" + dir
  # sqlDirPath에 폴더가 있는지 확인
  if os.path.exists(dirPath):
    logger.info('[makeDir] exists makeDirPath : '+ dirPath)

  else:
      os.makedirs(dirPath)
      logger.info('[makeDir] makedirs success : ' + dirPath)

# data 폴더 생성 및 이미지와 라벨 데이터 이동

logger.info('[logic]logic start')
makeDir(rootPath, 'data_annotated')

rootPath = "/content/drive/MyDrive/data_annotated"
makeDir(rootPath, 'Images')
makeDir(rootPath, 'MASKImages')

# images 이동
src = '/content/drive/MyDrive/sample_image/sample_image.png'
dest = '/content/drive/MyDrive/data_annotated/Images/sample_image.png'
os.replace(src, dest)

src = '/content/drive/MyDrive/sample_image/sample_image2.png'
dest = '/content/drive/MyDrive/data_annotated/Images/sample_image2.png'
os.replace(src, dest)

src = '/content/drive/MyDrive/sample_image/sample_image3.png'
dest = '/content/drive/MyDrive/data_annotated/Images/sample_image3.png'
os.replace(src, dest)

src = '/content/drive/MyDrive/sample_image/sample_image4.png'
dest = '/content/drive/MyDrive/data_annotated/Images/sample_image4.png'
os.replace(src, dest)

src = '/content/drive/MyDrive/sample_image/sample_image5.png'
dest = '/content/drive/MyDrive/data_annotated/Images/sample_image5.png'
os.replace(src, dest)

# mask 이동
src = '/content/drive/MyDrive/mask.png'
dest = '/content/drive/MyDrive/data_annotated/MASKImages/mask.png'
os.replace(src, dest)

src = '/content/drive/MyDrive/mask2.png'
dest = '/content/drive/MyDrive/data_annotated/MASKImages/mask2.png'
os.replace(src, dest)

src = '/content/drive/MyDrive/mask3.png'
dest = '/content/drive/MyDrive/data_annotated/MASKImages/mask3.png'
os.replace(src, dest)

src = '/content/drive/MyDrive/mask4.png'
dest = '/content/drive/MyDrive/data_annotated/MASKImages/mask4.png'
os.replace(src, dest)

src = '/content/drive/MyDrive/mask5.png'
dest = '/content/drive/MyDrive/data_annotated/MASKImages/mask5.png'
os.replace(src, dest)

# %%
IMAGE_SIZE = 512
BATCH_SIZE = 1
NUM_CLASSES = 1
DATA_DIR = "/content/data_annotated"
NUM_TRAIN_IMAGES = 2
NUM_VAL_IMAGES = 2

train_images = ['/content/drive/MyDrive/data_annotated/Images/sample_image.png', '/content/drive/MyDrive/data_annotated/Images/sample_image2.png']
train_masks = ['/content/drive/MyDrive/data_annotated/MASKImages/mask.png', '/content/drive/MyDrive/data_annotated/MASKImages/mask2.png']
val_images = ['/content/drive/MyDrive/data_annotated/Images/sample_image3.png', '/content/drive/MyDrive/data_annotated/Images/sample_image4.png']
val_masks =['/content/drive/MyDrive/data_annotated/MASKImages/mask3.png', '/content/drive/MyDrive/data_annotated/MASKImages/mask4.png']

# %%
def read_image(image_path, mask=False):
    image = tf.io.read_file(image_path)
    if mask:
        image = tf.image.decode_png(image, channels=1)
        image.set_shape([None, None, 1])
        image = tf.image.resize(images=image, size=[IMAGE_SIZE, IMAGE_SIZE])
    else:
        image = tf.image.decode_png(image, channels=3)
        image.set_shape([None, None, 3])
        image = tf.image.resize(images=image, size=[IMAGE_SIZE, IMAGE_SIZE])
        image = tf.keras.applications.resnet50.preprocess_input(image)
    return image


def load_data(image_list, mask_list):
    image = read_image(image_list)
    mask = read_image(mask_list, mask=True)
    return image, mask


def data_generator(image_list, mask_list):
    dataset = tf.data.Dataset.from_tensor_slices((image_list, mask_list))
    dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    return dataset


train_dataset = data_generator(train_images, train_masks)
val_dataset = data_generator(val_images, val_masks)

print("Train Dataset:", train_dataset)
print("Val Dataset:", val_dataset)
# Out:
# Train Dataset: <_BatchDataset element_spec=(TensorSpec(shape=(1, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(1, 512, 512, 1), dtype=tf.float32, name=None))>
# Val Dataset: <_BatchDataset element_spec=(TensorSpec(shape=(1, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(1, 512, 512, 1), dtype=tf.float32, name=None))>

# %%
def convolution_block(
    block_input,
    num_filters=256,
    kernel_size=3,
    dilation_rate=1,
    padding="same",
    use_bias=False,
):
    x = layers.Conv2D(
        num_filters,
        kernel_size=kernel_size,
        dilation_rate=dilation_rate,
        padding="same",
        use_bias=use_bias,
        kernel_initializer=keras.initializers.HeNormal(),
    )(block_input)
    x = layers.BatchNormalization()(x)
    return tf.nn.relu(x)


def DilatedSpatialPyramidPooling(dspp_input):
    dims = dspp_input.shape
    x = layers.AveragePooling2D(pool_size=(dims[-3], dims[-2]))(dspp_input)
    x = convolution_block(x, kernel_size=1, use_bias=True)
    out_pool = layers.UpSampling2D(
        size=(dims[-3] // x.shape[1], dims[-2] // x.shape[2]), interpolation="bilinear",
    )(x)

    out_1 = convolution_block(dspp_input, kernel_size=1, dilation_rate=1)
    out_6 = convolution_block(dspp_input, kernel_size=3, dilation_rate=6)
    out_12 = convolution_block(dspp_input, kernel_size=3, dilation_rate=12)
    out_18 = convolution_block(dspp_input, kernel_size=3, dilation_rate=18)

    x = layers.Concatenate(axis=-1)([out_pool, out_1, out_6, out_12, out_18])
    output = convolution_block(x, kernel_size=1)
    return output

def DeeplabV3Plus(image_size, num_classes):
    model_input = keras.Input(shape=(image_size, image_size, 3))
    resnet50 = keras.applications.ResNet50(
        weights="imagenet", include_top=False, input_tensor=model_input
    )
    x = resnet50.get_layer("conv4_block6_2_relu").output
    x = DilatedSpatialPyramidPooling(x)

    input_a = layers.UpSampling2D(
        size=(image_size // 4 // x.shape[1], image_size // 4 // x.shape[2]),
        interpolation="bilinear",
    )(x)
    input_b = resnet50.get_layer("conv2_block3_2_relu").output
    input_b = convolution_block(input_b, num_filters=48, kernel_size=1)

    x = layers.Concatenate(axis=-1)([input_a, input_b])
    x = convolution_block(x)
    x = convolution_block(x)
    x = layers.UpSampling2D(
        size=(image_size // x.shape[1], image_size // x.shape[2]),
        interpolation="bilinear",
    )(x)
    model_output = layers.Conv2D(num_classes, kernel_size=(1, 1), padding="same")(x)
    #model_output = layers.Dense(13, activation='softmax')(model_output)
    return keras.Model(inputs=model_input, outputs=model_output)

# %%
model = DeeplabV3Plus(image_size=IMAGE_SIZE, num_classes=NUM_CLASSES)
model.summary()

from keras.optimizers import Adam

# 모델 컴파일 시 Adam 옵티마이저를 사용하고 learning rate를 설정
initial_learning_rate = 0.003
optimizer = Adam(learning_rate=initial_learning_rate)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(train_dataset, validation_data=val_dataset, epochs=1)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_2 (InputLayer)        [(None, 512, 512, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 518, 518, 3)          0         ['input_2[0][0]']
#
#  conv1_conv (Conv2D)         (None, 256, 256, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 256, 256, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 256, 256, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 258, 258, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 128, 128, 64)         0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 128, 128, 64)         4160      ['pool1_pool[0][0]']
#  D)
#
# ...

# %% [markdown]
# ### 코드는 위 항목에서 오류가 난 채로 끝났음.
#
# 만일 위의 history 함수가 제대로 작동했다면 아래의 코드를 통해 정확도를 확인할 수 있었을 것으로 생각된다.
# 저는... 여기까지가 한계였던 것 같습니다...
# 정말 너무 힘들었네요...
# 그래도... 뿌듯하네요... 오늘도 좋은 하루 되세요...

# %%
import matplotlib.pyplot as plt
import cv2

plt.plot(history.history["loss"])
plt.title("Training Loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.savefig('traing_loss_epoch.png')

plt.plot(history.history["accuracy"])
plt.title("Training Accuracy")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.savefig('train_accuracy_epoch.png')

plt.plot(history.history["val_loss"])
plt.title("Validation Loss")
plt.ylabel("val_loss")
plt.xlabel("epoch")
plt.savefig('validation_accuracy_epoch.png')

plt.plot(history.history["val_accuracy"])
plt.title("Validation Accuracy")
plt.ylabel("val_accuracy")
plt.xlabel("epoch")
plt.savefig('validation_accuracy_epoch.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-b0d6ce3af0c0> in <cell line: 4>()
#       2 import cv2
#       3
# ----> 4 plt.plot(history.history["loss"])
#       5 plt.title("Training Loss")
#       6 plt.ylabel("loss")
#
# NameError: name 'history' is not defined
